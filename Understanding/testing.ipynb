# %%
x="""currentAcceleration [-0.009346008,-0.006866455,0.01487732]
Magnetometer_Vector [-23082.08,17083.5,37624.12]
currentChangeRateOfEulerAngle [-1.196289,-7.556152,-107.1411]
CurrentEulerAngles [359.9457,359.185,348.5373]"""

# %%
def parse_angles():

    ser = 'CurrentEulerAngles ['
    angs = x[x.find(ser)+len(ser):-1]
    angles = [int(float(ang)) for ang in  angs.split(',')]
    return angles
# Out:
# [359, 359, 348]
